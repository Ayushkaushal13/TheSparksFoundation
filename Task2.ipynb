# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushkaushal13/TheSparksFoundation/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing modules
import pandas as pd
import sklearn.datasets as datasets
from sklearn.tree import export_graphviz,DecisionTreeClassifier

# %%
#Loading dataset
iris=datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
print(df)
y=iris.target
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
#Splitting the data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df,y)

# %%
#Assigning model
dtree=DecisionTreeClassifier()
dtree.fit(X_train,y_train)
print("Decision Tree Created!")
# Out:
# Decision Tree Created!

# %%
#Evaluating model
score=dtree.score(X_test,y_test)
print(score)
# Out:
# 0.9473684210526315

# %%
# !pip install pydotplus
# !apt-get install graphviz -y
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# graphviz is already the newest version (2.42.2-6).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
#Creating dot file
export_graphviz(dtree,out_file="tree.dot")

# %%
#Converting to image
import pydotplus
dot_data=open("tree.dot","r").read()
graph=pydotplus.graph_from_dot_data(dot_data)
graph.write_png("tree.png")
# Out:
# True

# %%
#Displaying image
from IPython.display import Image
Image("tree.png")
